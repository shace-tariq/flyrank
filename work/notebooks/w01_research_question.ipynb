# %% [markdown]
# <a href="https://colab.research.google.com/github/shace-tariq/flyrank/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shace-tariq/flyrank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Content Refresh Prioritization
# I chose Content Refresh Prioritization to explore how observable page-level signals can help a content team prioritize which pages to review first. The starter dataset provides key signals such as impressions, CTR, average position, content age, and update age. By combining these metrics, I aim to develop a systematic, data-driven ranking method that moves beyond intuition-based decisions for content review prioritization.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The SEO or content team will use the ranking to decide which pages to review first. An incorrect recommendation could waste editors' time on pages that dont require attention, while missing a priority could delay necessary reviews. Therefore, I will evaluate the ranking as a decision-support tool by measuring its ranking performance, rather than attempting to explain why a page's performance changed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains 30,000 content items across 32 clients and 44 columns. It contains observable page-level signals such as impressions, CTR, average position, content age, and update age. The variation in these signals provides enough information to investigate whether pages can be prioritized more systematically for content review.

# %%
# !git clone https://github.com/shace-tariq/flyrank.git
# Out:
# Cloning into 'flyrank'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 123 (delta 37), reused 95 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 1.85 MiB | 14.01 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %%
# %cd /content/flyrank
# Out:
# /content/flyrank

# %%
import os

print("Current directory:", os.getcwd())
print(
    "Dataset exists:",
    os.path.exists("data/raw/content_refresh_anonymized.csv")
)
# Out:
# Current directory: /content/flyrank
# Dataset exists: True

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Clients:", df["client_id"].nunique())
# Out:
# Rows: 30000
# Columns: 44
# Clients: 32

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# I can report observed and directional relationships between the available page-level signals and evaluate whether different ranking approaches provide useful decision-support. I can measure ranking performance using metrics such as Precision@K. I cannot claim that a particular page characteristic causes performance to improve or decline, that changing a feature will definitely increase traffic or rankings, or that the model predicts Google's algorithm. The goal is to provide evidence that can help prioritize human review, not to prove causation or replace human judgment.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
